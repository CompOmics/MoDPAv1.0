# %%
from Map_and_count_peptides import get_peptidoforms_counts_mapped
from Relative_counts import get_relative_ptms
from Generate_PTM_matrices import generate_ptm_submatrices
from Combine_PTM_matrices import combine_ptm_submatrices

# %%
_prefix     = "Validation-20260812"
_fasta      = "./Human_2026_01_canonical.fasta.gz"
_pep_counts = "./v0113-2026/unprocessed/20260220_Peptidoforms_counts_v0113_breast_cancer.csv.gz"
# "./v0113-2026/unprocessed/20260220_Peptidoforms_counts_v0113_HamletAnnotated.csv.gz"
_pep_ids    = "./v0113-2026/unprocessed/20260220_Peptidoforms_IDs_v0113.csv.gz"
_myptms     = "./PTMs-of-interest-submission.csv"

# %%
PATH = get_peptidoforms_counts_mapped(
    _pep_ids,
    _pep_counts,
    _fasta,
    p=_prefix
)
# Out:
# The output prefix is: Validation-20260812
# Mapping peptides to proteins...
# Parsing .fasta file...
# 100%|██████████████████████████████████████████████████████████████████████████| 20416/20416 [00:09<00:00, 2234.91it/s]
# Calculating unique peptide counts per protein...
# Selecting leading proteins...
# IDs table length: 3,430,504
# Mapped_IDs table length: 3,147,340
# (283,164 IDs discarded)
# shape: (5, 12)
# ┌────────────────┬────────────┬─────────────┬────────────────┬───┬───────────┬──────────┬─────────────┬────────────────┐
# │ peptidoform_id ┆ peptide_id ┆ is_modified ┆ sequence       ┆ … ┆ pep_start ┆ LeadProt ┆ LeadEntry   ┆ all_UniAcc     │
# │ ---            ┆ ---        ┆ ---         ┆ ---            ┆   ┆ ---       ┆ ---      ┆ ---         ┆ ---            │
# │ i64            ┆ i64        ┆ str         ┆ str            ┆   ┆ i64       ┆ str      ┆ str         ┆ str            │
# ╞════════════════╪════════════╪═════════════╪════════════════╪═══╪═══════════╪══════════╪═════════════╪════════════════╡
# │ 47978          ┆ 3833961    ┆ t           ┆ VIHDNFGIVEGLMT ┆ … ┆ 163       ┆ P04406   ┆ G3P_HUMAN   ┆ P04406         │
# │                ┆            ┆             ┆ TVHAITATQK     ┆   ┆           ┆          ┆             ┆                │
# │ 125689         ┆ 931344     ┆ t           ┆ MSDGLFLQK      ┆ … ┆ 206       ┆ P50213   ┆ IDH3A_HUMAN ┆ P50213         │
# │ 271610         ┆ 241155     ┆ t           ┆ SHCIAEVENDEMPA ┆ … ┆ 311       ┆ P02768   ┆ ALBU_HUMAN  ┆ P02768         │
# │                ┆            ┆             ┆ DLPSLAADFVESK  ┆   ┆           ┆          ┆             ┆                │
# │ 271610         ┆ 241155     ┆ t           ┆ SHCIAEVENDEMPA ┆ … ┆ 311       ┆ P02768   ┆ ALBU_HUMAN  ┆ P02768         │
# │                ┆            ┆             ┆ DLPSLAADFVESK  ┆   ┆           ┆          ┆             ┆                │
# │ 307203         ┆ 1345273    ┆ t           ┆ CPEALFQPSFLGME ┆ … ┆ 257       ┆ P60709   ┆ ACTB_HUMAN  ┆ P60709||P63261 │
# │                ┆            ┆             ┆ SCGIHETTFNSIMK ┆   ┆           ┆          ┆             ┆                │
# └────────────────┴────────────┴─────────────┴────────────────┴───┴───────────┴──────────┴─────────────┴────────────────┘
# (5957602, 3)
# (1586440, 12)
# (5560212, 14)
# #peptidoforms = 1,586,440
# Unique peptidoforms: (1586440, 12)
# _
# is_modified
# True     1458733
# False     127707
# Name: count, dtype: int64
# % Unmodified peptides = 8.0%
#
# Mapped peptidoforms with counts: (5560212, 14)
# Saved mapped peptidoforms with counts to: Validation-20260812_Peptidoforms_counts_mapped.csv.gz

# %%
PATH = get_relative_ptms(PATH)
# Out:
# 1 / 785
# 2 / 785
# 3 / 785
# 4 / 785
# 5 / 785
# 6 / 785
# 7 / 785
# 8 / 785
# 9 / 785
# 10 / 785
# 11 / 785
# 12 / 785
# 13 / 785
# 14 / 785
# 15 / 785
# 16 / 785
# 17 / 785
# 18 / 785
# 19 / 785
# 20 / 785
# 21 / 785
# 22 / 785
# 23 / 785
# 24 / 785
# 25 / 785
# 26 / 785
# 27 / 785
# 28 / 785
# 29 / 785
# 30 / 785
# 31 / 785
# 32 / 785
# 33 / 785
# 34 / 785
# 35 / 785
# 36 / 785
# 37 / 785
# 38 / 785
# 39 / 785
# 40 / 785
# 41 / 785
# 42 / 785
# 43 / 785
# 44 / 785
# 45 / 785
# 46 / 785
# 47 / 785
# 48 / 785
# 49 / 785
# 50 / 785
# 51 / 785
# 52 / 785
# 53 / 785
# 54 / 785
# 55 / 785
# 56 / 785
# 57 / 785
# 58 / 785
# 59 / 785
# 60 / 785
# 61 / 785
# 62 / 785
# 63 / 785
# 64 / 785
# 65 / 785
# 66 / 785
# 67 / 785
# 68 / 785
# 69 / 785
# 70 / 785
# 71 / 785
# 72 / 785
# 73 / 785
# 74 / 785
# 75 / 785
# 76 / 785
# 77 / 785
# 78 / 785
# 79 / 785
# 80 / 785
# 81 / 785
# 82 / 785
# 83 / 785
# 84 / 785
# 85 / 785
# 86 / 785
# 87 / 785
# 88 / 785
# 89 / 785
# 90 / 785
# 91 / 785
# 92 / 785
# 93 / 785
# 94 / 785
# 95 / 785
# 96 / 785
# 97 / 785
# 98 / 785
# 99 / 785
# 100 / 785
# 101 / 785
# 102 / 785
# 103 / 785
# 104 / 785
# 105 / 785
# 106 / 785
# 107 / 785
# 108 / 785
# 109 / 785
# 110 / 785
# 111 / 785
# 112 / 785
# 113 / 785
# 114 / 785
# 115 / 785
# 116 / 785
# 117 / 785
# 118 / 785
# 119 / 785
# 120 / 785
# 121 / 785
# 122 / 785
# 123 / 785
# 124 / 785
# 125 / 785
# 126 / 785
# 127 / 785
# 128 / 785
# 129 / 785
# 130 / 785
# 131 / 785
# 132 / 785
# 133 / 785
# 134 / 785
# 135 / 785
# 136 / 785
# 137 / 785
# 138 / 785
# 139 / 785
# 140 / 785
# 141 / 785
# 142 / 785
# 143 / 785
# 144 / 785
# 145 / 785
# 146 / 785
# 147 / 785
# 148 / 785
# 149 / 785
# 150 / 785
# 151 / 785
# 152 / 785
# 153 / 785
# 154 / 785
# 155 / 785
# 156 / 785
# 157 / 785
# 158 / 785
# 159 / 785
# 160 / 785
# 161 / 785
# 162 / 785
# 163 / 785
# 164 / 785
# 165 / 785
# 744 / 785
# 745 / 785
# 746 / 785
# 747 / 785
# 748 / 785
# 749 / 785
# 750 / 785
# 751 / 785
# 752 / 785
# 753 / 785
# 754 / 785
# 755 / 785
# 756 / 785
# 757 / 785
# 758 / 785
# 759 / 785
# 760 / 785
# 761 / 785
# 762 / 785
# 763 / 785
# 764 / 785
# 765 / 785
# 766 / 785
# 767 / 785
# 768 / 785
# 769 / 785
# 770 / 785
# 771 / 785
# 772 / 785
# 773 / 785
# 774 / 785
# 775 / 785
# 776 / 785
# 777 / 785
# 778 / 785
# 779 / 785
# 780 / 785
# 781 / 785
# 782 / 785
# 783 / 785
# 784 / 785
# 785 / 785
# # files with usable data: 784
# Relative PTM counts saved to: Validation-20260812_PTMs_counts_relative.csv.gz

# %%
PATH = generate_ptm_submatrices(
    PATH,
    target_fasta_path="./Human_2026_01_canonical.fasta.gz",
    contam_fasta_path="./MQcontaminants_2023_11_14.fasta.gz",
    myptms=_myptms
)
# Out:
# # Target proteins = 20416
# # Contaminants = 197
# Shape after filtering: (578848, 7)
# PTMs in dataset:
# shape: (893, 1)
# ┌─────────────────────────────────┐
# │ ptm_name                        │
# │ ---                             │
# │ str                             │
# ╞═════════════════════════════════╡
# │ [9999150]Hex(1)HexNAc(1)Phos(1… │
# │ [361]Thrbiotinhydrazide         │
# │ [2027]His+O(2)                  │
# │ [1262]2-dimethylsuccinyl        │
# │ [9999877]dHex(2)Hex(1)HexNAc(2… │
# │ …                               │
# │ [9999515]HexNAc                 │
# │ [1264]pupylation                │
# │ [261]SPITC                      │
# │ [1279]Difuran                   │
# │ [9999882]dHex(2)Hex(2)          │
# └─────────────────────────────────┘
# #Raw files = 782
# #Modifications = 121034
# ptm_name
# [0]Unmod                                          276450
# [21]Phospho                                        87444
# [40]Sulfo                                          49248
# [35]Oxidation                                      39053
# [4]Carbamidomethyl                                 18257
#                                                    ...
# [9999336]Hex(3)HexNAc(3)Sulf(1)                        1
# [9999711]dHex(1)Hex(2)HexNAc(1)Sulf(1)                 1
# [9999713]dHex(1)Hex(2)HexNAc(2)NeuAc(1)Sulf(1)         1
# [9999283]Hex(2)HexNAc(4)                               1
# [539]Biotin:Cayman-10013                               1
# Name: count, Length: 893, dtype: int64
# [('K', 1, 'Acetyl'), ('R', 7, 'Deamidated'), ('S', 21, 'Phospho'), ('T', 21, 'Phospho'), ('Y', 21, 'Phospho'), ('S', 23, 'Dehydrated'), ('T', 23, 'Dehydrated'), ('Y', 23, 'Dehydrated'), ('K', 34, 'Methyl'), ('R', 34, 'Methyl'), ('R', 36, 'Dimethyl'), ('K', 37, 'Trimethyl'), ('C', 53, 'HNE'), ('H', 53, 'HNE'), ('K', 53, 'HNE'), ('K', 64, 'Succinyl'), ('D', 299, 'Carboxy'), ('E', 299, 'Carboxy'), ('K', 299, 'Carboxy'), ('K', 535, 'LRGG')]
# 1 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[1]Acetyl_K.pkl.gz 2156 74
# 2 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[7]Deamidated_R.pkl.gz 73060 1166
# 3 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[21]Phospho_S.pkl.gz 2142855 50361
# 4 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[21]Phospho_T.pkl.gz 241605 4974
# 5 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[21]Phospho_Y.pkl.gz 55080 1793
# 6 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[23]Dehydrated_S.pkl.gz 13122 224
# 7 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[23]Dehydrated_T.pkl.gz 4992 118
# 8 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[23]Dehydrated_Y.pkl.gz 154 16
# 9 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[34]Methyl_K.pkl.gz 10965 251
# 10 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[34]Methyl_R.pkl.gz 1728 96
# 11 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[36]Dimethyl_R.pkl.gz 3432 115
# 12 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[37]Trimethyl_K.pkl.gz 640 41
# 13 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[53]HNE_C.pkl.gz 40 8
# 14 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[53]HNE_H.pkl.gz 975 99
# 15 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[53]HNE_K.pkl.gz 1725 107
# 16 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[64]Succinyl_K.pkl.gz 150 19
# 17 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[299]Carboxy_D.pkl.gz 1824 70
# 18 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[299]Carboxy_E.pkl.gz 1739 71
# 19 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[299]Carboxy_K.pkl.gz 640 38
# 20 / 20 	 MoDPA_matrices_Validation-20260812/MoDPA_Rel_[535]LRGG_K.pkl.gz 15 6

# %%
combine_ptm_submatrices(
    PATH,
    prefix=_prefix,
    myptms=_myptms
)
# Out:
# 1 / 20 ('K', 1, 'Acetyl')
# (4, 49)
# 2 / 20 ('R', 7, 'Deamidated')
# (97, 281)
# 3 / 20 ('S', 21, 'Phospho')
# (3131, 351)
# 4 / 20 ('T', 21, 'Phospho')
# (294, 295)
# 5 / 20 ('Y', 21, 'Phospho')
# (79, 270)
# 6 / 20 ('S', 23, 'Dehydrated')
# (5, 162)
# 7 / 20 ('T', 23, 'Dehydrated')
# (7, 96)
# 8 / 20 ('Y', 23, 'Dehydrated')
# (2, 14)
# 9 / 20 ('K', 34, 'Methyl')
# (32, 129)
# 10 / 20 ('R', 34, 'Methyl')
# (4, 72)
# 11 / 20 ('R', 36, 'Dimethyl')
# (8, 78)
# 12 / 20 ('K', 37, 'Trimethyl')
# (3, 40)
# 13 / 20 ('C', 53, 'HNE')
# (0, 8)
# 14 / 20 ('H', 53, 'HNE')
# (4, 75)
# 15 / 20 ('K', 53, 'HNE')
# (7, 69)
# 16 / 20 ('K', 64, 'Succinyl')
# (1, 15)
# 17 / 20 ('D', 299, 'Carboxy')
# (2, 38)
# 18 / 20 ('E', 299, 'Carboxy')
# (3, 37)
# 19 / 20 ('K', 299, 'Carboxy')
# (1, 32)
# 20 / 20 ('K', 535, 'LRGG')
# (1, 5)
# sanity check: (3685, 526) | (3685, 2116)
# Dataset size = (3685, 526)
# # Proteins = 1070
# # PTMs     = 3685
# value range = [np.float64(0.002), np.float64(0.969)]
# Exp Name = Validation-20260812-PTMs-thresh5r5c-std0.05
# MoDPA size = (2251, 316)
# % nonzero cells = 6.78%
#
# PTM counts summary:
#               MOD  count
# 0     [21]Phospho   2181
# 1   [7]Deamidated     50
# 2         [53]HNE      6
# 3    [36]Dimethyl      5
# 4      [34]Methyl      4
# 5  [23]Dehydrated      2
# 6   [37]Trimethyl      2
# 7       [1]Acetyl      1
# 'MoDPA_matrices_Validation-20260812\\Validation-20260812-PTMs-thresh5r5c-std0.05.pkl.gz'

# %% [markdown]
# -------------
